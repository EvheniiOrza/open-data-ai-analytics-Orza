# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/reestrtz01.01.2026.csv', sep=';', encoding='cp1251')

# Візуалізація розподілу за типом палива
df['FUEL'].value_counts().plot(kind='bar', title='Розподіл за типом палива')
plt.show()
