# %%
import pandas as pd

# Завантаження (враховуй кодування cp1251 для українських даних)
df = pd.read_csv('../data/reestrtz01.01.2026.csv', sep=';', encoding='cp1251')

# Перевірка на пропуски
print(df.isnull().sum())

# Перевірка типів даних
print(df.info())
